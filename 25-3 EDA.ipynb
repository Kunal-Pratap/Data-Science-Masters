# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('flight_price.xlsx')

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %% [markdown]
# ## Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
df.shape
# Out:
# (10683, 11)

# %%
## It has 10683 rows and 11 columns

# %% [markdown]
# ## Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.

# %%
sns.histplot(data=df,x=df['Price'],kde=True,color='g')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %% [markdown]
# ## Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
df['Price'].describe()
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %%
## Minimun price is 1759 and maximun price is 79512

# %% [markdown]
# ## Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x=df['Airline'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Airline', ylabel='Price'>

# %% [markdown]
# ## Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
## Yes there are outliers in the dataset. 
## Due to outliers mean gets cganged.
## Model is not trained well.

# %% [markdown]
# ## Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %%
## we will analyse date of journey column.
df['date_day']=df['Date_of_Journey'].str.split('/').str[0]
df['date_month']=df['Date_of_Journey'].str.split('/').str[1]
df['date_year']=df['Date_of_Journey'].str.split('/').str[2]

# %%
df['date_day']=df['date_day'].astype(int)
df['date_month']=df['date_month'].astype(int)
df['date_year']=df['date_year'].astype(int)

# %%
sns.histplot(data=df,x='Price',y='date_month',kde=True)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='date_month'>

# %% [markdown]
# ## Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?

# %%
sns.histplot(data=df,x='Price')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
## We will analyse which airline person is using
## What are source and destination.
## What is duration of time.
## How many number of stops it has.
## And on which day we are going by flight.

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
#
#    date_day  date_month  date_year
# 0        24           3       2019
# 1         1           5       2019

# %% [markdown]
# ## Q8. You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?

# %%
## We will analyse which airline person is using
## What are source and destination.
## What is duration of time.
## How many number of stops it has.
## And on which day we are going by flight.

# %% [markdown]
# ## Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
df = pd.read_csv('googleplaystore.csv')

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df.shape
# Out:
# (10841, 13)

# %%
## It has 13 columns and 10841 rows.

# %% [markdown]
# ## Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.

# %%
df['Rating']=df['Rating'].fillna(4.16)

# %%
df['Rating'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df,x='Rating',y='Category')
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Category'>

# %% [markdown]
# ## Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may impact your analysis.

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %%
## Yes there are some missing values.
## We can fill missing values by mean,median,mode intutation.
## They play very crusial role as we get errors in code.
## model might be trained in wrong way.

# %% [markdown]
# ## Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df['Size']= df['Size'].str.replace('M','000')
df['Size']= df['Size'].str.replace('k','')
##df['Size']= df['Size'].
df['Size']= df['Size'].str.replace(',','')
df['Size']= df['Size'].replace('Varies with device','1.000')
##df['Size']=df['Size'].astype(float)

# %%
df['Size']= df['Size'].str.replace('+','')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17076\2798752640.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Size']= df['Size'].str.replace('+','')

# %%
df['Size']=df['Size'].astype(float)

# %%
chars_to_remove=['+',',','$']
cols_to_clean=['Installs','Price']
for item in chars_to_remove:
    for cols in cols_to_clean:
        df[cols]=df[cols].str.replace(item,'')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_17076\2031856696.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[cols]=df[cols].str.replace(item,'')

# %%
df['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        'Everyone', '1.20', '1.04'], dtype=object)

# %%
df['Price']=df['Price'].replace('Everyone',np.nan)
df['Price'].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26', nan,
#        '1.20', '1.04'], dtype=object)

# %%
df['Price']=df['Price'].astype(float)

# %%
df['Price']=df['Price'].fillna(1.02)

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(data=df,x='Size',y='Price')
# Out:
# <AxesSubplot:xlabel='Size', ylabel='Price'>

# %% [markdown]
# ## Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews     Size Installs  Type  Price Content Rating  \
# 0     159  19000.0    10000  Free    0.0       Everyone
# 1     967  14000.0   500000  Free    0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df[df['Type'].isnull()]
# Out:
#                             App Category  Rating Reviews  Size Installs Type  \
# 9148  Command & Conquer: Rivals   FAMILY    4.16       0   1.0        0  NaN
#
#       Price Content Rating    Genres   Last Updated         Current Ver  \
# 9148    0.0   Everyone 10+  Strategy  June 28, 2018  Varies with device
#
#              Android Ver
# 9148  Varies with device

# %%
df['Type'].describe()
# Out:
# count     10840
# unique        3
# top        Free
# freq      10039
# Name: Type, dtype: object

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %%
df['Type'].mode()
# Out:
# 0    Free
# Name: Type, dtype: object

# %%
df['Type']=df['Type'].fillna('Free')

# %%
df['Type'].isnull().sum()
# Out:
# 0

# %%
sns.barplot(x='Type',y='Price',data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Price'>

# %% [markdown]
# ## Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest number of installs.

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews     Size Installs  Type  Price Content Rating  \
# 0     159  19000.0    10000  Free    0.0       Everyone
# 1     967  14000.0   500000  Free    0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df['Category'].value_counts().plot.pie(y=df['Category'],figsize=(15,16),autopct='%1.1f')
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
category = pd.DataFrame(df['Category'].value_counts())        #Dataframe of apps on the basis of category
category.rename(columns = {'Category':'Count'},inplace=True)

# %%
category
# Out:
#                      Count
# FAMILY                1972
# GAME                  1144
# TOOLS                  843
# MEDICAL                463
# BUSINESS               460
# PRODUCTIVITY           424
# PERSONALIZATION        392
# COMMUNICATION          387
# SPORTS                 384
# LIFESTYLE              382
# FINANCE                366
# HEALTH_AND_FITNESS     341
# PHOTOGRAPHY            335
# SOCIAL                 295
# NEWS_AND_MAGAZINES     283
# SHOPPING               260
# TRAVEL_AND_LOCAL       258
# DATING                 234
# BOOKS_AND_REFERENCE    231
# VIDEO_PLAYERS          175
# EDUCATION              156
# ENTERTAINMENT          149
# MAPS_AND_NAVIGATION    137
# FOOD_AND_DRINK         127
# HOUSE_AND_HOME          88
# LIBRARIES_AND_DEMO      85
# AUTO_AND_VEHICLES       85
# WEATHER                 82
# ART_AND_DESIGN          65
# EVENTS                  64
# PARENTING               60
# COMICS                  60
# BEAUTY                  53
# ...

# %% [markdown]
# ## Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the company?

# %%
## We will analyse price
## we will analyse app column 
## Also we will analysis installs column

# %% [markdown]
# ## Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the most successful app developers. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews     Size Installs  Type  Price Content Rating  \
# 0     159  19000.0    10000  Free    0.0       Everyone
# 1     967  14000.0   500000  Free    0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
## we will analyse Retings as more ratings more good app is.
## WE will analysis reviews of app.
## We will also analysis the installs column.

# %% [markdown]
# ## Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to launch a new app. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %%
## We will analyse the Android version column.
## We will also analyse current version.
## we will use Bar plot to show visualization.
